# %% [markdown]
# <a href="https://colab.research.google.com/github/katearb/test_case/blob/master/Data_exploring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Задание

# %% [markdown]
# Необходимо написать скрипт для парсинга диалогов из файла test_data.csv. Получившийся скрипт необходимо выложить в гит репозиторий и прислать ссылку в качестве результата прохождения тестового задания. Данные выкладывать в гит не следует.
# Главные задачи, которые должен выполнять скрипт:
# * Извлекать реплики с приветствием – где менеджер поздоровался.
# * Извлекать реплики, где менеджер представил себя.
# * Извлекать имя менеджера.
# * Извлекать название компании.
# * Извлекать реплики, где менеджер попрощался.
#
# Проверять требование к менеджеру: «В каждом диалоге обязательно необходимо поздороваться и попрощаться с клиентом»

# %%
import pandas as pd
from typing import List

# %% [markdown]
# # Первичный анализ

# %% [markdown]
# Первым делом познакомимся с данными и ответим на вопросы:
# * Что из себя представляет датасет?
# * Какие данные там содержатся?
# * Что из себя представляет отдельная строка и как строки связаны между собой?
#
# А также охарактеризуем тексты с различных сторон.

# %%
def get_dialogues(data: pd.DataFrame) -> List[str]:
  """
  Returns the dialogues in form of a string with lines and roles for futher printing
  """

  roles = data.groupby('dlg_id')['role'].apply(list)
  dialogues = data.groupby('dlg_id')['text'].apply(list)

  role_dialogues_joint = [[*zip(d_roles, texts)] 
                                    for d_roles, texts in zip(roles, dialogues)]

  role_dialogues_str = ['\n'.join([': '.join(line) for line in dialogue]) 
                                          for dialogue in role_dialogues_joint]

  return role_dialogues_str

# %%
# load the data
data = pd.read_csv('/content/drive/MyDrive/test_data.csv')

# %%
data.head(10)
# Out:
#    dlg_id  line_n     role                                               text
# 0       0       0   client                                               Алло
# 1       0       1  manager                                  Алло здравствуйте
# 2       0       2   client                                        Добрый день
# 3       0       3  manager  Меня зовут ангелина компания диджитал бизнес з...
# 4       0       4   client                                                Ага
# 5       0       5  manager  Угу ну возможно вы рассмотрите и другие вариан...
# 6       0       6   client  Да мы работаем с компанией которая нам подлива...
# 7       0       7   client  Как как бы уже до этого момента работаем все у...
# 8       0       8  manager      Угу а на что вы обращаете внимание при выборе
# 9       0       9   client                                         Как бы нет

# %%
print(get_dialogues(data)[0])
# Out:
# client: Алло
# manager: Алло здравствуйте
# client: Добрый день
# manager: Меня зовут ангелина компания диджитал бизнес звоним вам по поводу продления лицензии а мы с серым у вас скоро срок заканчивается
# client: Ага
# manager: Угу ну возможно вы рассмотрите и другие варианты видите это хорошая практика сравнивать
# client: Да мы работаем с компанией которая нам подливает поэтому спасибо огромное
# client: Как как бы уже до этого момента работаем все устраивает + у нас сопровождение поэтому
# manager: Угу а на что вы обращаете внимание при выборе
# client: Как бы нет
# client: Да на выбор я уже не обращаю внимание я уже дома выбрал
# manager: Что для вас приоритет
# client: Поэтому типа много параметров
# client: Выбор не выбор есть история сотрудничества которая более важна потому что вот смотрите вы же мне 1 раз звоните
# client: А работаем мы там а уже давно а почему звоните только сейчас а не в течении своего времени когда работают
# manager: Ну у вас срок заканчивается поэтому мы набрали + ко всему
# client: Совершенно верно да и вот так вот делает еще 50 компаний которые звонят
# client: И спрашивают продвигают продлевать
# client: Ну вот я просто каждый раз удивляюсь почему нельзя позвонить во время когда
# client: Хирам работает вот если вы хотите меня заполучить
# client: А в следующий раз как клиента
# client: Сделайте мне 3 звонка в следующий период и спросите может быть проведите аудист нет
# client: Сделайте что нибудь
# client: Незначительная но бесплатная и покажите свою компетентность а вот
# client: Как мне выбирать вас по каким параметрам потому что вы рассказываете я человек который 18 лет работает пролажен рассказать нужно все что угодно отработать возражения можно предложить какие то услуги выгодные
# client: + месяц 2 3 все что угодно
# client: Ну лояльности спрашивается 2 месяц не показывает не показывает и вот так вот все работают с вашей сферой кто работает с самой сферой мне все звонят
# client: Последний момент с предложением продлить
# client: А вот компания в которой я работаю
# manager: А так нет не только поэтому просто я обратила внимание и вы пользуетесь виджетами мы там с вами сотрудничали
# client: А как будет недостаточно хорошие качественные услуги
# client: И меня все исключительно за то что вы мне как то рассказываете мне очень
# client: Ага
# client: Да
# manager: А если вы 19 являетесь то лучше то идти бесплатно
# client: Слушайте очень сложно сказать потому что виджетов достаточно много не все
# manager: Ага хорошо
# client: А настроены подключены от разных компаний поэтому как бы
# client: Не могу сказать я прошу прощения просто я да так наверное не очень
# client: А а да но ну действительно это так то что я сказал что
# client: Э стоп вот там самый
# client: Полтора года и меня все время действительно удивляет
# client: А просто извините свой подход немножко в целом компании я вам даю просто хорошую качественную обратную связь которую возможно
# client: Особо не дает
# client: Контакты с клиентами вне формате их завершения лицензии
# manager: Индивидуальным поэтому не все то есть сотрудничают с кем то сейчас да кому то например не с кем сейчас справляться кто то сравнивал
# client: Потому что вы звоните и ну то есть
# client: Смотрите у меня есть история годичная работа с компанией которая у меня в принципе устраивает которая у меня контакт
# client: О сопровождении они не только там
# client: Предлагают и у меня нареканий нет
# client: Это хорошая компания и 110
# client: А компании которые
# client: И
# client: То есть я не понимаю как вот просто подумайте как люди как клиенты которым вы звоните
# client: Должны изменить свое решение
# client: По отношению к вашей компании
# client: То есть у меня есть годичная история работы без каких либо нареканий
# client: И вот менеджеры которые мне звонят и предлагают
# client: Пробить через них
# client: По какой причине я должен принять решение в вашу пользу
# client: Переключен просто нет
# client: Есть
# manager: Да мы услышали вас спасибо за рекомендации
# client: Да да есть такая штуковина ну то есть
# client: Получается так что
# client: Из конверсии той базы которую вы обзваниваете
# client: Скорее всего вы получите в контракт людей у которых либо же печальное сотрудничество с предыдущей компанией
# client: Либо у кого его вообще нету
# client: Ну не факт что вы не можете получить допустим меня
# client: В контакте
# client: Да делайте аудиты ну то есть
# client: Там для вас это
# client: Вообще копейки и не так много времени
# client: А давайте рекомендации и тогда но если эти рекомендации и аудит даст мне реально пользу
# client: Больше и та компания которая сейчас работает не видит
# client: Да
# client: Ну то есть это как бы простой
# manager: Вот понимаю да но дело в том что в основном да за месяц
# client: Такой простой шаг который в принципе можете делать
# client: Э ну я не понимаю почему и никто не делает
# client: Алло
# client: А вот эти честно ну я просто уже забиваю со счета какую
# client: По счету это компания которая звонит
# client: У меня
# client: Решать договор
# client: И вот за месяц
# client: Завершения мне звонят из компании
# client: И на 15 честно это вызывает
# client: То что я не понимаю
# client: Что хотите услышать но исключительно если только
# client: Да у меня по случаю есть
# client: Ага
# manager: Необходимо обзванивать
# client: Ага
# manager: Хорошо я данную информацию тогда зафиксирую передам будем иметь ввиду
# client: Ну просто подумайте подумайте вашей командой как вы можете
# client: Потому что это ну вот эти звонки за месяц до окончания
# client: Мне конечно интересно какая у вас конверсия там допустим не 1000 человек которые вы обзваниваете
# client: Сколько людей соглашаются
# client: Ну опять же
# client: Тем более если у вас есть виджеты
# client: Если нет бесплатно если у вас видно а кто ваш
# client: Это все можете использовать для вашей же пользы
# client: Честно я не понимаю как у вас в продаже если что вы все работаете отдельно
# client: Никто вот
# client: Да спасибо огромное
# manager: И вам спасибо большое за обратную связь
# client: Угу
# manager: Всего хорошего до свидания

# %% [markdown]
# *(простите за лонгрид 😥)*
#
# **Что стало известно от структуре датасета**:
# * Датасет содержит реплики телефонных разговоров между менеджерами и клиентами.
# * Одна строка датафрейма содержит один небольшой относительно самостоятельный отрезок высказывания, однако является лишь частью целой реплики. Рискну преположить, деление производилось по фонетическому признаку, а именно по паузам в речи.
#
# * Для каждой реплики представлена информация об авторе, о принадлежности к отельному диалогу и ее позиция в этом отдельном диалоге.
#
# *  Для проверки соблюдения требований менеджером будет необходимо сгруппировать данные по диалогам.
#
# **Что известно от репликах**
#
# Текст -- затранскрибированные телефонные разговоры. При работе с таким родом текстов могут возникнуть следующие сложности:
# 1. Отсутствие заглавных букв в именах собственных и названиях компаний (а ведь это то, что нам и нужно найти:( ), а также знаков препинания.
# 2. Ошибки в распознавании речи
# 3. Сам факт устной речи со всеми ее особенностями: слова-паразиты, повторения, заикания, ошибки, частая несвязанность в высказывании.

# %% [markdown]
# **Общие замечания:**
# 1. Приветствия и прощания являются частью речевого этикета. Их особенность -- наличие устойчивых, стереотипных формулы в обращении. А значит, основываясь на анализе типичных формул приветствия и прощания среди менеджеров, можно выявить эти сами *паттерны* и по ним обнаружить в тексте необходимую информацию.
# 2. В моем представлении, "менеджер представляет себя" и "менеджер называет свое имя" -- одна и та же информация. Поэтому тэг "manager_self_represented" будет иметь флаг в тех репликах, где удалось обнаружить имя менеджера.
#
# 2. При извлечении имен также можно положиться на *паттерны* саморепрезентации ("Меня зовут X", "Я Y"), коллекцию имен и типичное расположение саморепрезентации в начале диалога. Аналогично для названий компаний.
#
# 3. Извлечение имен компаний -- достаточно сложная задача, а на русском языке до сих пор нет хорошего инструмента. Чтобы достичь наилучшего результата, для решения этой задачи я буду полагаться на 2 инструмента: парсинг по правилам и нахождение совпадений по набору известных компаний.
#
# Для оценки соблюдения менеджером требований можно составить отдельный отчет по каждому диалогу.
#
# **Возможные инструменты для решения задачи:**
# 1. Первый и самый очевидный: регулярные выражения. Выше я не раз говорила формулы и паттерны, для извелечения которых регулярки подходят отлично.
# 2. Можно создавать правила и воспользоваться парером Yargi.
# 3. Был бы рамеченный текст, можно было бы обучить какой-нибудь алгоритм для решения NER задачи, однако за неимением разметки, этот вариант отметается. Да и данных для обучения у нас не так много.
# 4. Синтаксическая и морфологическая разметка могла бы дать дополнительную информацию, однако она здесь кажется избыточной и неуместной с учетом специфики текстовой информации. Также мне кажется, что лексической информации должно хватить для выполнения задач.
#
# Таким образом, система ругулярных выражений и ивристических правил должна здесь справиться.
#
# **Этапы работы:**
# 1. Проанализировать предложенные тексты, выявить паттерны для каждого типа интересующей информации.
# 2. Подключить к анализу лингвистическую экспертизу и собственные знания о языке, чтобы составить паттерны для регулярных выражений и правила, которые будут разнообразны и будут работать хорошо не только на этих текстах, но и на тех, которые мы не видели (То есть постараться не переобучиться и показать свою обобщающую способность на максимуме :) )
# 3. Построить систему для удобного использования.
#
# Собственно, в этом ноутбуке будет находиться анализ, а имплементация работающего решения в отдельном .py файле.
#
# Я заранее разделю данные на обучающую и тестовую выборки. В рамках анализа я буду ориенироваться только на первую часть, а на второй проверять, как хорошо справляется мое решение.
# Конечно больно принимать такое решение, потому что данных у нас не так уж и много...но хочется хоть как-то провалидроваться.

# %% [markdown]
# # Train/test split

# %%
# choose the test samples
import random
random.seed(12)
test_ids = random.sample(range(2, 6), k=2)  # 0 and 1 are not included as I have already seen them

print('Test samples are', test_ids)
# Out:
# Test samples are [5, 3]

# %%
# define train and test data
data_train = data[~data['dlg_id'].isin(test_ids)]
data_test = data[data['dlg_id'].isin(test_ids)]

# %%
# check shape
data_train.shape, data_test.shape
# Out:
# ((284, 4), (196, 4))

# %% [markdown]
# # Изучение текстов

# %%
# investigate the texts
for dlg in get_dialogues(data_train):
  print('======'*10)
  print(dlg)
# Out:
# ============================================================
# client: Алло
# manager: Алло здравствуйте
# client: Добрый день
# manager: Меня зовут ангелина компания диджитал бизнес звоним вам по поводу продления лицензии а мы с серым у вас скоро срок заканчивается
# client: Ага
# manager: Угу ну возможно вы рассмотрите и другие варианты видите это хорошая практика сравнивать
# client: Да мы работаем с компанией которая нам подливает поэтому спасибо огромное
# client: Как как бы уже до этого момента работаем все устраивает + у нас сопровождение поэтому
# manager: Угу а на что вы обращаете внимание при выборе
# client: Как бы нет
# client: Да на выбор я уже не обращаю внимание я уже дома выбрал
# manager: Что для вас приоритет
# client: Поэтому типа много параметров
# client: Выбор не выбор есть история сотрудничества которая более важна потому что вот смотрите вы же мне 1 раз звоните
# client: А работаем мы там а уже давно а почему звоните только сейчас а не в течении своего времени когда работают
# manager: Ну у вас срок заканчивается поэтому мы набрали + ко всему
# client: Совершенно верно да и вот так вот делает еще 50 компаний которые звонят
# client: И спрашивают продвигают продлевать
# client: Ну вот я просто каждый раз удивляюсь почему нельзя позвонить во время когда
# client: Хирам работает вот если вы хотите меня заполучить
# client: А в следующий раз как клиента
# client: Сделайте мне 3 звонка в следующий период и спросите может быть проведите аудист нет
# client: Сделайте что нибудь
# client: Незначительная но бесплатная и покажите свою компетентность а вот
# client: Как мне выбирать вас по каким параметрам потому что вы рассказываете я человек который 18 лет работает пролажен рассказать нужно все что угодно отработать возражения можно предложить какие то услуги выгодные
# client: + месяц 2 3 все что угодно
# client: Ну лояльности спрашивается 2 месяц не показывает не показывает и вот так вот все работают с вашей сферой кто работает с самой сферой мне все звонят
# client: Последний момент с предложением продлить
# client: А вот компания в которой я работаю
# manager: А так нет не только поэтому просто я обратила внимание и вы пользуетесь виджетами мы там с вами сотрудничали
# client: А как будет недостаточно хорошие качественные услуги
# client: И меня все исключительно за то что вы мне как то рассказываете мне очень
# client: Ага
# client: Да
# manager: А если вы 19 являетесь то лучше то идти бесплатно
# client: Слушайте очень сложно сказать потому что виджетов достаточно много не все
# manager: Ага хорошо
# client: А настроены подключены от разных компаний поэтому как бы
# client: Не могу сказать я прошу прощения просто я да так наверное не очень
# client: А а да но ну действительно это так то что я сказал что
# client: Э стоп вот там самый
# client: Полтора года и меня все время действительно удивляет
# client: А просто извините свой подход немножко в целом компании я вам даю просто хорошую качественную обратную связь которую возможно
# client: Особо не дает
# client: Контакты с клиентами вне формате их завершения лицензии
# manager: Индивидуальным поэтому не все то есть сотрудничают с кем то сейчас да кому то например не с кем сейчас справляться кто то сравнивал
# client: Потому что вы звоните и ну то есть
# client: Смотрите у меня есть история годичная работа с компанией которая у меня в принципе устраивает которая у меня контакт
# client: О сопровождении они не только там
# client: Предлагают и у меня нареканий нет
# client: Это хорошая компания и 110
# client: А компании которые
# client: И
# client: То есть я не понимаю как вот просто подумайте как люди как клиенты которым вы звоните
# client: Должны изменить свое решение
# client: По отношению к вашей компании
# client: То есть у меня есть годичная история работы без каких либо нареканий
# client: И вот менеджеры которые мне звонят и предлагают
# client: Пробить через них
# client: По какой причине я должен принять решение в вашу пользу
# client: Переключен просто нет
# client: Есть
# manager: Да мы услышали вас спасибо за рекомендации
# client: Да да есть такая штуковина ну то есть
# client: Получается так что
# client: Из конверсии той базы которую вы обзваниваете
# client: Скорее всего вы получите в контракт людей у которых либо же печальное сотрудничество с предыдущей компанией
# client: Либо у кого его вообще нету
# client: Ну не факт что вы не можете получить допустим меня
# client: В контакте
# client: Да делайте аудиты ну то есть
# client: Там для вас это
# client: Вообще копейки и не так много времени
# client: А давайте рекомендации и тогда но если эти рекомендации и аудит даст мне реально пользу
# client: Больше и та компания которая сейчас работает не видит
# client: Да
# client: Ну то есть это как бы простой
# manager: Вот понимаю да но дело в том что в основном да за месяц
# client: Такой простой шаг который в принципе можете делать
# client: Э ну я не понимаю почему и никто не делает
# client: Алло
# client: А вот эти честно ну я просто уже забиваю со счета какую
# client: По счету это компания которая звонит
# client: У меня
# client: Решать договор
# client: И вот за месяц
# client: Завершения мне звонят из компании
# client: И на 15 честно это вызывает
# client: То что я не понимаю
# client: Что хотите услышать но исключительно если только
# client: Да у меня по случаю есть
# client: Ага
# manager: Необходимо обзванивать
# client: Ага
# manager: Хорошо я данную информацию тогда зафиксирую передам будем иметь ввиду
# client: Ну просто подумайте подумайте вашей командой как вы можете
# client: Потому что это ну вот эти звонки за месяц до окончания
# client: Мне конечно интересно какая у вас конверсия там допустим не 1000 человек которые вы обзваниваете
# client: Сколько людей соглашаются
# client: Ну опять же
# client: Тем более если у вас есть виджеты
# client: Если нет бесплатно если у вас видно а кто ваш
# client: Это все можете использовать для вашей же пользы
# client: Честно я не понимаю как у вас в продаже если что вы все работаете отдельно
# client: Никто вот
# client: Да спасибо огромное
# manager: И вам спасибо большое за обратную связь
# client: Угу
# manager: Всего хорошего до свидания
# ============================================================
# client: Да здравствуйте когда заканчивается
# manager: Алло здравствуйте
# manager: Меня зовут ангелина компания диджитал бизнес звоню вам по поводу продления а мы сели обратила внимание что у вас срок заканчивается
# manager: А так у вас заканчивается 25 февраля
# manager: На полгода минимальный
# client: 25 февраля минимальный срок продления какой есть
# manager: А у вас сейчас 8 базовый правильно
# client: Сейчас секунду 6 месяцев у меня
# client: Сколько будет стоить на текущее количество пользователей
# client: Что
# manager: 8 пользователей указан правильно
# client: Не знаю не знаю сейчас посмотрю но у меня
# manager: Угу
# client: 1 2 3 4 5 у меня вообще 5 активных
# client: Мне пока больше не надо наверное
# client: Так сейчас секунду 1 2 3
# client: 65 а нет не там еще 1 2 3 4 5 нет правильно ну допустим 6 6 месяцев вот на 6 человек
# manager: Нашей да а тариф базовый на 6 месяцев это 17964 р
# client: Так 6 пользователей еще раз скажите пожалуйста 17000
# manager: Да 17964
# client: 564 р тогда такой вопрос и это допустим сейчас у меня вот сказали 8 я сделаю можно сделать расчет ну то есть ну как 3 пользователей и как то продлить тем самым нет
# manager: Да конечно вам просто нужно будет зайти в настройки а мы серым а убрать там пользователей а после этого написать в техподдержку а маш что вот вы убрали подтвердите что сейчас вам
# client: Алло
# manager: А а вот вверху у вас там будет как настройки знаете
# client: Сейчас прямо здесь скажите пожалуйста в пользователя надо зайти или куда
# client: Да ну я здесь
# manager: И там будет
# client: Ну вот сейчас секунду тут есть фильтр сейчас
# manager: Да вот где раздел как для админа там вам нужно будет туда зайти и там будет количество пользователей там где активировать
# manager: Угу
# client: Все все все сейчас активные пользователи и не активные пользователи
# manager: 5 пользователей да сейчас я тогда проверю по вашему партнерскому кабинету 1 секунду
# client: Так ну 1 2 3
# client: У меня кстати также 5 5 пользователей
# client: Да сейчас 783-67-02
# manager: Так в очень странно мне просто указано 8 может это старая информация не обновленная
# manager: А могли бы назвать ваш номер аккаунта
# manager: 783-67-02 правильно
# client: Да
# manager: Угу да сейчас 1 секунду я посмотрю тогда
# manager: По вашему техническому кабинету
# manager: Так да по партнерскому у вас 5 пользователей все правильно тогда обновлю у себя информацию а тогда ничего не нужно будет делать просто я вам посылаю счет и
# client: 25 февраля да
# manager: Все то есть как стандартная
# manager: Да у вас 25 февраля заканчивается угу
# client: Хорошо я так подумаю вот и там дальше с вами свяжусь что как дальше
# manager: Угу хорошо я тогда вам информацию продублирую чтобы вы ознакомились в сравнении так сказать
# manager: А куда вам можно на ватсап например
# client: Нет ну можете на почту
# manager: Давайте тогда почту проверим инфо собачка эра черточка 3 дэ точка ру правильно
# client: Самое только вместо инфо денис дэ е эн
# manager: Угу
# client: И с точкой
# manager: Угу да вижу я эту почту хорошо тогда исправлю на эту будем ждать ответа всего хорошего
# manager: До свидания
# ============================================================
# client: Алло
# client: Здравствуйте
# manager: Алло здравствуйте
# manager: Меня зовут ангелина компания диджитал бизнес звоню вам по поводу продления лицензии а мастера мы с вами сотрудничали по видео там
# manager: А нет я еще не отправляла я решила вам набрать
# client: Ну разговаривать удобно да
# manager: Удобно вам сейчас говорить что я вам так рассказала
# manager: Угу хорошо а вы сейчас подскажите по каким критериям выбираете партнера чтобы мы могли подготовить для вас предложение
# client: Так цена и эти индексации какие есть
# manager: Угу я поняла ну по стоимости везде одинаковые по официальным партнерам
# client: Да цена у всех одинаковая там
# manager: Поэтому могу сказать вот по преимуществам то есть если про преимущества то у нас более 20 виджетов вам идет бесплатно а там же идет кэшбэк 20% вам эта сумма возвращается то есть когда то что вы можете
# client: Так ваша компания как называется
# manager: Диджитал бизнес
# manager: Здесь же это у бизнес
# client: Так там на севере
# client: Так
# client: Да ага вижу
# manager: Я вам еще раз говорю на ватсап предложение
# client: Угу
# manager: Вот и смотрите на счет кэшбэка то что у вас кэшбэк 20% вы за эту сумму можете например приобрести какой то бизнес процесс который будет для вас более актуально то есть для именно вашего бизнеса например там автоматизация в воронке да либо же
# client: Так
# manager: Контроль например отказов то есть только для вас подойдет для этого вам наш аналитик уже подберет что для вас будет более актуально поэтому я хотела бы вам предложить встречу там на 15 20 минут
# manager: У вас будут окошки там например на следующей неделе
# manager: Вы нашли да наш сайт
# client: Подсветка сделок
# client: Да да да
# manager: Угу
# client: Так значит у вас пишет и все
# manager: А подскажите тогда что вам нужно чтобы вы могли подготовить индивидуальное предложение
# client: И что нам нужно
# client: Да
# client: Нам нужна интеграция с ватсапа
# manager: Угу
# manager: Угу
# client: Нам нужна этот удаление дублей
# client: И нам нужно этот
# client: Виджет который
# client: Как вот так сейчас сейчас я вам еще точно скажу я у меня не списывается
# client: Потом нам нужен виджет который
# client: А сделать обязательно несколько раз
# manager: Группировка полей да
# client: Не не не грузируется делает обязательно
# manager: А выделение на диск
# manager: Угу
# client: Да
# manager: А ну вот насчет выделения потом подсветки это по процентам есть а насчет вот интеграции как бы как можно реализовать то есть мы приобретаем эту интеграцию а вы можете ее оплатить например кэшбэком
# client: Пока что так
# client: Угу понял хорошо
# manager: С кэшбэка у вас 20% идет от суммы которую оплачиваете
# manager: Вот а
# client: А вы мне можете помочь
# manager: Не подскажете вот
# client: Коммерческая
# manager: Да конечно вам на ватсап или на почту
# client: Можете скинуть
# client: Коммерческая
# client: Не
# manager: Угу на почту
# client: Можно на подключится
# client: Ну вы мне это
# manager: Так давайте тогда проверим смотрите тут просто 2 почты есть почта
# client: Да да да на почте меньше
# client: Нет нет
# manager: Сапаров собачка
# manager: А вот астана собачка ираклас точка кз
# client: Она нет тоже нету да
# manager: Еще раз
# client: Жесупов собачка аэропорт
# manager: Угу
# client: Или вы мне напишите новое
# manager: Не перепутала оставлю тогда на ватсап хорошо а за счет времени вы не сориентировали у вас вот на следующей неделе когда будет чтобы созвониться с бизнес аналитиком
# client: Угу у нас еще неделя но давайте до среды решим этот
# manager: Угу
# client: Так
# manager: У вас в любое время есть с какого по какого
# manager: Что что
# manager: А в любое время хорошо тогда я аналитику по этому вопросу напишу а он мне тоже напишет свои окошки а я вам в ватсап
# client: Угу
# client: Угу хорошо
# manager: Напишу что будет да
# client: Угу
# manager: Хорошо тогда сейчас вам отправлю и звоните на следующей неделе
# client: Угу хорошо
# manager: Все хорошо
# ============================================================
# client: Алло
# client: Алло
# client: Добрый
# manager: Вот по виду платежи пообщаться помните мы вот с вами обсуждали вас там 1 функционал не очень в нашем продукте подходил вот по промежуточным задачам вот а скажите пожалуйста а сейчас этот вопрос актуален для вас
# client: Угу
# client: Ну в принципе да
# manager: Я понял ну мы хотели бы просто предложить такой вариант развития событий в принципе мы
# client: Угу
# manager: Готовы будем для вашего клиента это использовать работать вот
# manager: Наверное в рамках недели полторы наверное займет вот но так как мы будем приобретете поэтому если нет каких то других соответственно условия которые мешают вам его приобрести то я вам предлагаю просто предложить это видеть клиенту вот его оплачивать
# client: А на сколько можно идти
# client: Понятно а оплата на сколько должна быть на этот раз
# manager: Да мы на год принимаем оплату
# client: Угу
# manager: Да так
# client: Давайте я предложу
# client: Хорошо и вы имеете ввиду доработку какую это когда
# manager: А вот а ну вот помните айдар вам не подходило то что вот вы ставили конечную дату платежа и у вас промежуточные платежи по ним задачи вот не выставляли то есть вы получали задачу на конечную дату вот и вот это было ну тем фактором который вам не подошел именно в этом виде этих платежей вот а
# client: Там что как галочки просто вылезли да читались
# client: Угу
# client: Ну не только задача эти под под не запускается
# client: Ну вот вот вот им же главное чтобы
# manager: А я понял ну да да да тогда вот вот эти вот вещи мы их готовы учесть будем
# client: Клиентам уходило напоминание об очередном платеже
# client: Угу
# manager: Хорошо я дам ну да да обсудите
# client: А в какой форме это вот ответ возьмите
# manager: А если про саму форму ну то есть вы получите там ну наверное подтверждение и какая форма обязательства нужно ну то есть что требуется для того чтобы на ну собственно для вас это было приемлемо там я не знаю там письмо какое то там или какая то там еще информация ну то есть вы как скажете давайте так попробуем договориться
# client: Если что угу
# manager: Ну вот
# client: Хорошо я понял да у меня с ним связь будет в понедельник
# manager: Давайте
# manager: Все тогда а вас когда вам когда лучше тогда на сайт позвонить в понедельник или во вторник лучше
# manager: Во вторник все ну с вами да тогда до вторника до свидания
# client: Угу да до свидания

# %% [markdown]
# 1. Приветствия:
#   * 0-2. здравствуйте (отрезок 0)
#   * 4 . -
# 2. Самопредставление и имя менеджера:
#   * 0-2. Меня зовут ангелина (отрезок 1)
#   * 4 . -
#
# 3. Название компании:
#   * 0-2. [Меня зовут ангелина] компания диджитал бизнес (отрезок 1)
#   * 4 . -
#
# 4. Прощание:
#   1. Всего хорошего до свидания (отрезки -2, -1)
#   2. До свидания (отрезок -1)
#   3. -
#   4. до свидания (отрезок -1)

# %% [markdown]
# Получилось не много. Видимо, в нашу выборку попала только Ангелина и еще какой-то анонимный менеджер. Время подключать свой опыт, справочники по речевому этикету и знания о языке.

# %% [markdown]
# # Подбор разнообразных шаблонов

# %% [markdown]
# * Еще возможные приветствия: добрый день, доброе утро, добрый вечер.
#
#   Есть также неформальные варианты, которыми менеджер не должен пользоваться, однако перед нами стоит задача выявления наличия приветствия вне заивисмости от того, насколько оно корректно. Поэтому, можем рассмотреть и такие варианты: привет, приветствую, с добрым утром.
#
# * Еще формулы представления себя менеджером:
#   * это [менеджер] X [компания|из компании],
#   * вам звонит X [компания|из компании],
#   * [компания Y] [менеджер] X,
#   * меня зовут X я работаю в компании,
#   * вас беспокоит X [компания|из компании]
#
#   Менеджеры как правило представляются только по имени.
#
# * Еще формулы представления компании:
#   * [приветствие] из компании Y,
#   * офис/подразделение Y,
#   * [приветствие] фирма/из фирмы Y,
#   * [приветствие] Y,
#   * из Y.
#
#   Вообще, типов организаций очень много, и все они потенциально могут стоять здесь вместо слова "компания": стоматология, банк, магазин, студия, и многие-многие другие. Расширение этого списка зависит от того, какие встречаютя в данных. В наших данных нет никаких специфческих обозначений, поэтому оставим это для будущего улучшения парсера.
#
# * Еще прощания: хорошего дня, всего доброго, хорошего вечера.
#
#   Из неформальных: пока, до скорого.

# %% [markdown]
# Итак, мы выяснили типичные позиции тех или иных реплик в речи менеджера и паттерны для каждого типа информации. Следующий шаг, разработка шаблонов и создание скрипта. Это находится в файле DialoguesParser.py
